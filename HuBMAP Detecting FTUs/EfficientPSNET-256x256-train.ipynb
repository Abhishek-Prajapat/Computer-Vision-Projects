# %% [markdown]
# ## Imports

# %%
# !pip install efficientnet --upgrade -q
# !pip install segmentation_models -q --upgrade
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segmentation-models 1.0.1 requires efficientnet==1.0.0, but you have efficientnet 1.1.1 which is incompatible.

# %%
import os
import cv2
import glob
import shutil
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import segmentation_models as sm
import efficientnet.tfkeras as efn
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

from tqdm.notebook import tqdm
from sklearn.model_selection import KFold

import warnings
warnings.simplefilter('ignore')
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# ## Config

# %%
sm.set_framework('tf.keras')
sm.framework()
os.environ['SM_FRAMEWORK'] = 'tf.keras'

class Config:
  
  gcs_path = 'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828'
  SEED = 1234

  AUTO = tf.data.experimental.AUTOTUNE

  n_folds = 5
  img_size = [256, 256] # Resized to [384, 384]
  batch_size = 256

  backbone = 'efficientnetb0'
  epochs = 20
  lr = 1e-4

config = Config()

# %%
try: # detect TPUs
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver() # TPU detection
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except ValueError: # no TPU found, detect GPUs
    #strategy = tf.distribute.MirroredStrategy() # for GPU or multi-GPU machines
    strategy = tf.distribute.get_strategy() # default strategy that works on CPU and single GPU
    #strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy() # for clusters of multi-GPU machines

print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.40.2.74:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.40.2.74:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Number of accelerators:  8

# %% [markdown]
# ## GCS_PATHS

# %%
ALL_TRAINING_FILENAMES = tf.io.gfile.glob(config.gcs_path + '/train/*')
ALL_TRAINING_FILENAMES
# Out:
# ['gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/0486052bb-355.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/095bf7a1f-656.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/1e2425f28-586.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/26dc41664-794.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/2f6ecfcdf-324.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/4ef6695ce-1220.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/54f2eec69-299.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/8242609fa-770.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/aaa6a05cc-134.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/afa5e8098-1125.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/b2dc8411c-213.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/b9a3865fc-772.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/c68fe75ea-1136.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/cb2d976f4-888.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/e79de561c-308.tfrec']

# %%
import re
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)
print('NUM_TRAINING_IMAGES:' )
print(count_data_items(ALL_TRAINING_FILENAMES))
# Out:
# NUM_TRAINING_IMAGES:
# 9580

# %% [markdown]
# ## Creating Folds

# %%
ALL_TRAINING_FILENAMES = np.array(ALL_TRAINING_FILENAMES)

splitter = KFold(n_splits=5, random_state=config.SEED)

train_files = []
valid_files = []

for fold, (trn_, val_) in enumerate(splitter.split(range(len(ALL_TRAINING_FILENAMES)))):
  fold_train_files = ALL_TRAINING_FILENAMES[trn_]
  fold_valid_files = ALL_TRAINING_FILENAMES[val_]
  np.random.shuffle(fold_train_files)
  train_files.append(fold_train_files)
  valid_files.append(fold_valid_files)

# %% [markdown]
# ## Datasets pipeline

# %%
DIM = config.img_size[0]
def _parse_image_function(example_proto,augment = True):
    image_feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'mask': tf.io.FixedLenFeature([], tf.string)
    }
    single_example = tf.io.parse_single_example(example_proto, image_feature_description)
    image = tf.reshape(tf.io.decode_raw(single_example['image'], out_type=np.dtype('uint8')), (DIM,DIM, 3))
    mask =  tf.reshape(tf.io.decode_raw(single_example['mask'], out_type='uint8'), (DIM,DIM,1))
    image = tf.image.resize(image, (384, 384))
    mask = tf.image.resize(mask, (384, 384))
    mask = tf.cast(mask, dtype='bool')
    
    if augment:

        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        if tf.random.uniform(()) > 0.4:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        if tf.random.uniform(()) > 0.5:
            image = tf.image.rot90(image, k=1)
            mask = tf.image.rot90(mask, k=1)

        if tf.random.uniform(()) > 0.45:
            image = tf.image.random_saturation(image, 0.7, 1.3)

        if tf.random.uniform(()) > 0.45:
            image = tf.image.random_contrast(image, 0.8, 1.2)
    
    return tf.cast(image, tf.float32), tf.cast(mask, tf.float32)

def load_dataset(filenames, ordered=False, augment = True):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=config.AUTO)
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(lambda ex: _parse_image_function(ex, augment = augment), num_parallel_calls=config.AUTO)
    return dataset

def get_training_dataset(TRAINING_FILENAMES):
    dataset = load_dataset(TRAINING_FILENAMES)
    dataset = dataset.repeat()
    dataset = dataset.shuffle(128, seed = config.SEED)
    dataset = dataset.batch(config.batch_size,drop_remainder=True)
    dataset = dataset.prefetch(config.AUTO)
    return dataset

def get_validation_dataset(VALIDATION_FILENAMES, ordered=True):
    dataset = load_dataset(VALIDATION_FILENAMES, ordered=ordered, augment = False)
    dataset = dataset.batch(config.batch_size,drop_remainder=True)
    dataset = dataset.prefetch(config.AUTO)
    return dataset

# %%
ds = get_training_dataset(train_files[0])

# %%
for i in ds:
  print(i[0].shape, i[1].shape)
  break
# Out:
# (256, 384, 384, 3) (256, 384, 384, 1)

# %% [markdown]
# ## Metrics

# %%
# https://tensorlayer.readthedocs.io/en/latest/_modules/tensorlayer/cost.html#dice_coe
def dice_coe(output, target, axis = None, smooth=1e-10):
    output = tf.dtypes.cast( tf.math.greater(output, 0.5), tf. float32 )
    target = tf.dtypes.cast( tf.math.greater(target, 0.5), tf. float32 )
    inse = tf.reduce_sum(output * target, axis=axis)
    l = tf.reduce_sum(output, axis=axis)
    r = tf.reduce_sum(target, axis=axis)

    dice = (2. * inse + smooth) / (l + r + smooth)
    dice = tf.reduce_mean(dice, name='dice_coe')
    return dice

# https://www.kaggle.com/kool777/training-hubmap-eda-tf-keras-tpu
def tversky(y_true, y_pred, alpha=0.7, beta=0.3, smooth=1):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (true_pos + smooth) / (true_pos + alpha * false_neg + beta * false_pos + smooth)
def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)
def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return K.pow((1 - tv), gamma)

get_custom_objects().update({"focal_tversky": focal_tversky_loss})

# %% [markdown]
# ## Create Model

# %%
def get_model():
  model = sm.PSPNet(config.backbone, encoder_weights='imagenet', classes=1, activation='sigmoid', input_shape=(384, 384, 3))
  model.compile(optimizer = tf.keras.optimizers.Adam(lr = 0.00005),
                loss = sm.losses.bce_dice_loss,
                metrics=[dice_coe,'accuracy', sm.metrics.iou_score])
  return model

# %%
# Lr function
lr_start = 0.000005
lr_min = 0.00001
lr_max = 0.00000125 * 8 * 64
lr_decay = 0.8
lr_rampup = 3

def lrfn(epoch):
  if epoch <= lr_rampup:
    lr = (lr_max - lr_start)/lr_rampup * epoch + lr_min
  else:
    lr = (lr_max - lr_min) * lr_decay**(epoch - lr_rampup) + lr_min
  return lr

values = [lrfn(i) for i in range(10)]
plt.plot(values)

# %% [markdown]
# ## Run Fold function

# %%
def run_fold(fold, display_plot=True):
  tfiles = train_files[fold]
  vfiles = valid_files[fold]

  K.clear_session()
  with strategy.scope():
    model = get_model()

  checkpoint = tf.keras.callbacks.ModelCheckpoint('./content/drive/MyDrive/Projects/HuBMAP_Detect_FTU/PSNET-fold-%i.h5'%fold,
                                 monitor='val_dice_coe',patience = 10,
                                 mode='max',save_best_only=True)
  
  early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_dice_coe',mode = 'max', patience=10, restore_best_weights=True)

  lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=0)

  print(f'Training Model Fold {fold+1}...')
  history = model.fit(
      get_training_dataset(tfiles),
      epochs = config.epochs,
      steps_per_epoch = 9580//config.batch_size,
      callbacks = [checkpoint, lr_callback, early_stop],
      validation_data = get_validation_dataset(vfiles)
  )

  if display_plot:        
        plt.figure(figsize=(15,5))
        n_e = np.arange(len(history.history['dice_coe']))
        plt.plot(n_e,history.history['dice_coe'],'-o',label='Train dice_coe',color='#ff7f0e')
        plt.plot(n_e,history.history['val_dice_coe'],'-o',label='Val dice_coe',color='#1f77b4')
        x = np.argmax( history.history['val_dice_coe'] ); y = np.max( history.history['val_dice_coe'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max dice_coe\n%.2f'%y,size=14)
        plt.ylabel('dice_coe',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(n_e,history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(n_e,history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.legend(loc=3)
        plt.show()

  return history, model

# %% [markdown]
# ## Training the model

# %%
global_history = []

for fold in range(config.n_folds):
  history, _ = run_fold(fold)
  global_history.append(history)
# Out:
# Training Model Fold 1...
# Epoch 1/20
# 37/37 [==============================] - 40s 446ms/step - loss: 1.4704 - dice_coe: 0.0719 - accuracy: 0.7682 - iou_score: 0.0318 - val_loss: 1.2430 - val_dice_coe: 0.0178 - val_accuracy: 0.9460 - val_iou_score: 0.0373
# Epoch 2/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.7386 - dice_coe: 0.4993 - accuracy: 0.9728 - iou_score: 0.2361 - val_loss: 1.2955 - val_dice_coe: 0.0347 - val_accuracy: 0.9415 - val_iou_score: 0.0409
# Epoch 3/20
# 37/37 [==============================] - 11s 308ms/step - loss: 0.3855 - dice_coe: 0.7227 - accuracy: 0.9848 - iou_score: 0.5024 - val_loss: 1.0353 - val_dice_coe: 0.1069 - val_accuracy: 0.9632 - val_iou_score: 0.0881
# Epoch 4/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.3043 - dice_coe: 0.7741 - accuracy: 0.9877 - iou_score: 0.5905 - val_loss: 1.0381 - val_dice_coe: 0.1108 - val_accuracy: 0.9642 - val_iou_score: 0.0867
# Epoch 5/20
# 37/37 [==============================] - 11s 307ms/step - loss: 0.2697 - dice_coe: 0.7990 - accuracy: 0.9891 - iou_score: 0.6307 - val_loss: 0.4917 - val_dice_coe: 0.6100 - val_accuracy: 0.9781 - val_iou_score: 0.4299
# Epoch 6/20
# 37/37 [==============================] - 11s 305ms/step - loss: 0.2455 - dice_coe: 0.8175 - accuracy: 0.9898 - iou_score: 0.6619 - val_loss: 0.2825 - val_dice_coe: 0.8123 - val_accuracy: 0.9871 - val_iou_score: 0.6152
# Epoch 7/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.2275 - dice_coe: 0.8318 - accuracy: 0.9902 - iou_score: 0.6830 - val_loss: 0.2551 - val_dice_coe: 0.8196 - val_accuracy: 0.9877 - val_iou_score: 0.6542
# Epoch 8/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.2180 - dice_coe: 0.8381 - accuracy: 0.9907 - iou_score: 0.6937 - val_loss: 0.2369 - val_dice_coe: 0.8279 - val_accuracy: 0.9885 - val_iou_score: 0.6752
# Epoch 9/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.2083 - dice_coe: 0.8441 - accuracy: 0.9916 - iou_score: 0.7040 - val_loss: 0.3293 - val_dice_coe: 0.7456 - val_accuracy: 0.9842 - val_iou_score: 0.5883
# Epoch 10/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.2029 - dice_coe: 0.8484 - accuracy: 0.9915 - iou_score: 0.7105 - val_loss: 0.2436 - val_dice_coe: 0.8152 - val_accuracy: 0.9880 - val_iou_score: 0.6750
# Epoch 11/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.2042 - dice_coe: 0.8468 - accuracy: 0.9916 - iou_score: 0.7090 - val_loss: 0.2681 - val_dice_coe: 0.7977 - val_accuracy: 0.9869 - val_iou_score: 0.6545
# Epoch 12/20
# 37/37 [==============================] - 11s 308ms/step - loss: 0.1927 - dice_coe: 0.8564 - accuracy: 0.9917 - iou_score: 0.7244 - val_loss: 0.2125 - val_dice_coe: 0.8436 - val_accuracy: 0.9894 - val_iou_score: 0.7094
# Epoch 13/20
# 37/37 [==============================] - 11s 307ms/step - loss: 0.1911 - dice_coe: 0.8578 - accuracy: 0.9918 - iou_score: 0.7273 - val_loss: 0.2012 - val_dice_coe: 0.8530 - val_accuracy: 0.9898 - val_iou_score: 0.7234
# Epoch 14/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.1861 - dice_coe: 0.8611 - accuracy: 0.9923 - iou_score: 0.7311 - val_loss: 0.1943 - val_dice_coe: 0.8583 - val_accuracy: 0.9902 - val_iou_score: 0.7303
# Epoch 15/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.1842 - dice_coe: 0.8637 - accuracy: 0.9923 - iou_score: 0.7344 - val_loss: 0.1954 - val_dice_coe: 0.8556 - val_accuracy: 0.9901 - val_iou_score: 0.7307
# Epoch 16/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.1874 - dice_coe: 0.8596 - accuracy: 0.9924 - iou_score: 0.7294 - val_loss: 0.1958 - val_dice_coe: 0.8546 - val_accuracy: 0.9901 - val_iou_score: 0.7305
# Epoch 17/20
# 37/37 [==============================] - 11s 307ms/step - loss: 0.1854 - dice_coe: 0.8611 - accuracy: 0.9922 - iou_score: 0.7324 - val_loss: 0.2095 - val_dice_coe: 0.8428 - val_accuracy: 0.9895 - val_iou_score: 0.7167
# Epoch 18/20
# 37/37 [==============================] - 12s 320ms/step - loss: 0.1830 - dice_coe: 0.8634 - accuracy: 0.9921 - iou_score: 0.7371 - val_loss: 0.2016 - val_dice_coe: 0.8495 - val_accuracy: 0.9898 - val_iou_score: 0.7260
# Epoch 19/20
# 37/37 [==============================] - 11s 307ms/step - loss: 0.1782 - dice_coe: 0.8671 - accuracy: 0.9925 - iou_score: 0.7409 - val_loss: 0.1947 - val_dice_coe: 0.8557 - val_accuracy: 0.9901 - val_iou_score: 0.7335
# Epoch 20/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.1782 - dice_coe: 0.8678 - accuracy: 0.9928 - iou_score: 0.7407 - val_loss: 0.1940 - val_dice_coe: 0.8563 - val_accuracy: 0.9902 - val_iou_score: 0.7336
# Training Model Fold 2...
# Epoch 1/20
# 37/37 [==============================] - 40s 467ms/step - loss: 2.0073 - dice_coe: 0.0663 - accuracy: 0.1893 - iou_score: 0.0329 - val_loss: 1.4381 - val_dice_coe: 0.0570 - val_accuracy: 0.8108 - val_iou_score: 0.0346
# Epoch 2/20
# 37/37 [==============================] - 12s 317ms/step - loss: 0.8428 - dice_coe: 0.4525 - accuracy: 0.9440 - iou_score: 0.1961 - val_loss: 1.5469 - val_dice_coe: 0.0300 - val_accuracy: 0.8906 - val_iou_score: 0.0238
# Epoch 3/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.4101 - dice_coe: 0.7121 - accuracy: 0.9842 - iou_score: 0.4785 - val_loss: 1.0045 - val_dice_coe: 0.1029 - val_accuracy: 0.9567 - val_iou_score: 0.0826
# Epoch 4/20
# 37/37 [==============================] - 12s 316ms/step - loss: 0.3531 - dice_coe: 0.7374 - accuracy: 0.9866 - iou_score: 0.5395 - val_loss: 0.5723 - val_dice_coe: 0.6700 - val_accuracy: 0.9817 - val_iou_score: 0.3320
# Epoch 5/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.2866 - dice_coe: 0.7885 - accuracy: 0.9874 - iou_score: 0.6160 - val_loss: 0.3841 - val_dice_coe: 0.7741 - val_accuracy: 0.9870 - val_iou_score: 0.4957
# Epoch 6/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.2586 - dice_coe: 0.8059 - accuracy: 0.9893 - iou_score: 0.6482 - val_loss: 0.3528 - val_dice_coe: 0.7339 - val_accuracy: 0.9862 - val_iou_score: 0.5364
# Epoch 7/20
# 37/37 [==============================] - 12s 316ms/step - loss: 0.2476 - dice_coe: 0.8132 - accuracy: 0.9905 - iou_score: 0.6564 - val_loss: 0.4197 - val_dice_coe: 0.6573 - val_accuracy: 0.9834 - val_iou_score: 0.4795
# Epoch 8/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2238 - dice_coe: 0.8336 - accuracy: 0.9904 - iou_score: 0.6860 - val_loss: 0.2739 - val_dice_coe: 0.8189 - val_accuracy: 0.9884 - val_iou_score: 0.6205
# Epoch 9/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.2158 - dice_coe: 0.8398 - accuracy: 0.9908 - iou_score: 0.6951 - val_loss: 0.2367 - val_dice_coe: 0.8279 - val_accuracy: 0.9898 - val_iou_score: 0.6672
# Epoch 10/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.2223 - dice_coe: 0.8321 - accuracy: 0.9914 - iou_score: 0.6867 - val_loss: 0.2782 - val_dice_coe: 0.7851 - val_accuracy: 0.9882 - val_iou_score: 0.6264
# Epoch 11/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.2060 - dice_coe: 0.8470 - accuracy: 0.9912 - iou_score: 0.7070 - val_loss: 0.2583 - val_dice_coe: 0.7997 - val_accuracy: 0.9890 - val_iou_score: 0.6516
# Epoch 12/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.2003 - dice_coe: 0.8513 - accuracy: 0.9914 - iou_score: 0.7152 - val_loss: 0.2091 - val_dice_coe: 0.8458 - val_accuracy: 0.9906 - val_iou_score: 0.7043
# Epoch 13/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2090 - dice_coe: 0.8422 - accuracy: 0.9919 - iou_score: 0.7023 - val_loss: 0.2096 - val_dice_coe: 0.8453 - val_accuracy: 0.9907 - val_iou_score: 0.7038
# Epoch 14/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.1987 - dice_coe: 0.8509 - accuracy: 0.9917 - iou_score: 0.7156 - val_loss: 0.2214 - val_dice_coe: 0.8315 - val_accuracy: 0.9903 - val_iou_score: 0.6922
# Epoch 15/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.2003 - dice_coe: 0.8499 - accuracy: 0.9915 - iou_score: 0.7171 - val_loss: 0.2048 - val_dice_coe: 0.8492 - val_accuracy: 0.9909 - val_iou_score: 0.7085
# Epoch 16/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.1930 - dice_coe: 0.8550 - accuracy: 0.9922 - iou_score: 0.7231 - val_loss: 0.2009 - val_dice_coe: 0.8534 - val_accuracy: 0.9910 - val_iou_score: 0.7135
# Epoch 17/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.2021 - dice_coe: 0.8469 - accuracy: 0.9920 - iou_score: 0.7098 - val_loss: 0.2029 - val_dice_coe: 0.8543 - val_accuracy: 0.9909 - val_iou_score: 0.7105
# Epoch 18/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.1968 - dice_coe: 0.8515 - accuracy: 0.9917 - iou_score: 0.7214 - val_loss: 0.1984 - val_dice_coe: 0.8535 - val_accuracy: 0.9911 - val_iou_score: 0.7177
# Epoch 19/20
# 37/37 [==============================] - 12s 327ms/step - loss: 0.1857 - dice_coe: 0.8624 - accuracy: 0.9921 - iou_score: 0.7320 - val_loss: 0.1965 - val_dice_coe: 0.8552 - val_accuracy: 0.9912 - val_iou_score: 0.7192
# Epoch 20/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.2022 - dice_coe: 0.8467 - accuracy: 0.9924 - iou_score: 0.7094 - val_loss: 0.1975 - val_dice_coe: 0.8536 - val_accuracy: 0.9912 - val_iou_score: 0.7190
# Training Model Fold 3...
# Epoch 1/20
# 37/37 [==============================] - 40s 457ms/step - loss: 1.3163 - dice_coe: 0.0509 - accuracy: 0.9248 - iou_score: 0.0309 - val_loss: 2.5699 - val_dice_coe: 0.0530 - val_accuracy: 0.4942 - val_iou_score: 0.0310
# Epoch 2/20
# 37/37 [==============================] - 11s 303ms/step - loss: 0.6918 - dice_coe: 0.5087 - accuracy: 0.9767 - iou_score: 0.2607 - val_loss: 1.2951 - val_dice_coe: 0.0205 - val_accuracy: 0.9430 - val_iou_score: 0.0221
# Epoch 3/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.3739 - dice_coe: 0.7254 - accuracy: 0.9849 - iou_score: 0.5167 - val_loss: 1.0541 - val_dice_coe: 0.0766 - val_accuracy: 0.9595 - val_iou_score: 0.0726
# Epoch 4/20
# 37/37 [==============================] - 11s 300ms/step - loss: 0.3079 - dice_coe: 0.7696 - accuracy: 0.9871 - iou_score: 0.5911 - val_loss: 0.5102 - val_dice_coe: 0.6363 - val_accuracy: 0.9769 - val_iou_score: 0.3904
# Epoch 5/20
# 37/37 [==============================] - 11s 301ms/step - loss: 0.2674 - dice_coe: 0.7995 - accuracy: 0.9890 - iou_score: 0.6354 - val_loss: 0.3222 - val_dice_coe: 0.7804 - val_accuracy: 0.9843 - val_iou_score: 0.5740
# Epoch 6/20
# 37/37 [==============================] - 11s 300ms/step - loss: 0.2346 - dice_coe: 0.8242 - accuracy: 0.9901 - iou_score: 0.6730 - val_loss: 0.3267 - val_dice_coe: 0.7540 - val_accuracy: 0.9835 - val_iou_score: 0.5869
# Epoch 7/20
# 37/37 [==============================] - 11s 301ms/step - loss: 0.2258 - dice_coe: 0.8297 - accuracy: 0.9909 - iou_score: 0.6821 - val_loss: 0.3134 - val_dice_coe: 0.7610 - val_accuracy: 0.9842 - val_iou_score: 0.5992
# Epoch 8/20
# 37/37 [==============================] - 11s 307ms/step - loss: 0.2153 - dice_coe: 0.8379 - accuracy: 0.9912 - iou_score: 0.6947 - val_loss: 0.2457 - val_dice_coe: 0.8200 - val_accuracy: 0.9871 - val_iou_score: 0.6719
# Epoch 9/20
# 37/37 [==============================] - 11s 302ms/step - loss: 0.2043 - dice_coe: 0.8462 - accuracy: 0.9915 - iou_score: 0.7081 - val_loss: 0.2211 - val_dice_coe: 0.8410 - val_accuracy: 0.9882 - val_iou_score: 0.6981
# Epoch 10/20
# 37/37 [==============================] - 11s 299ms/step - loss: 0.2003 - dice_coe: 0.8500 - accuracy: 0.9917 - iou_score: 0.7125 - val_loss: 0.2904 - val_dice_coe: 0.7809 - val_accuracy: 0.9852 - val_iou_score: 0.6316
# Epoch 11/20
# 37/37 [==============================] - 11s 305ms/step - loss: 0.1964 - dice_coe: 0.8532 - accuracy: 0.9917 - iou_score: 0.7184 - val_loss: 0.2136 - val_dice_coe: 0.8430 - val_accuracy: 0.9885 - val_iou_score: 0.7117
# Epoch 12/20
# 37/37 [==============================] - 11s 303ms/step - loss: 0.1913 - dice_coe: 0.8572 - accuracy: 0.9918 - iou_score: 0.7249 - val_loss: 0.1921 - val_dice_coe: 0.8618 - val_accuracy: 0.9895 - val_iou_score: 0.7361
# Epoch 13/20
# 37/37 [==============================] - 11s 303ms/step - loss: 0.1878 - dice_coe: 0.8593 - accuracy: 0.9923 - iou_score: 0.7280 - val_loss: 0.2087 - val_dice_coe: 0.8466 - val_accuracy: 0.9889 - val_iou_score: 0.7207
# Epoch 14/20
# 37/37 [==============================] - 11s 306ms/step - loss: 0.1843 - dice_coe: 0.8624 - accuracy: 0.9922 - iou_score: 0.7332 - val_loss: 0.1869 - val_dice_coe: 0.8646 - val_accuracy: 0.9898 - val_iou_score: 0.7448
# Epoch 15/20
# 37/37 [==============================] - 11s 302ms/step - loss: 0.1859 - dice_coe: 0.8599 - accuracy: 0.9924 - iou_score: 0.7299 - val_loss: 0.1838 - val_dice_coe: 0.8675 - val_accuracy: 0.9900 - val_iou_score: 0.7473
# Epoch 16/20
# 37/37 [==============================] - 12s 316ms/step - loss: 0.1871 - dice_coe: 0.8591 - accuracy: 0.9924 - iou_score: 0.7293 - val_loss: 0.1829 - val_dice_coe: 0.8691 - val_accuracy: 0.9899 - val_iou_score: 0.7483
# Epoch 17/20
# 37/37 [==============================] - 11s 301ms/step - loss: 0.1792 - dice_coe: 0.8661 - accuracy: 0.9925 - iou_score: 0.7392 - val_loss: 0.1835 - val_dice_coe: 0.8681 - val_accuracy: 0.9900 - val_iou_score: 0.7482
# Epoch 18/20
# 37/37 [==============================] - 11s 303ms/step - loss: 0.1781 - dice_coe: 0.8667 - accuracy: 0.9924 - iou_score: 0.7413 - val_loss: 0.1812 - val_dice_coe: 0.8699 - val_accuracy: 0.9901 - val_iou_score: 0.7507
# Epoch 19/20
# 37/37 [==============================] - 11s 302ms/step - loss: 0.1799 - dice_coe: 0.8653 - accuracy: 0.9925 - iou_score: 0.7396 - val_loss: 0.1809 - val_dice_coe: 0.8698 - val_accuracy: 0.9901 - val_iou_score: 0.7513
# Epoch 20/20
# 37/37 [==============================] - 11s 305ms/step - loss: 0.1773 - dice_coe: 0.8676 - accuracy: 0.9926 - iou_score: 0.7416 - val_loss: 0.1792 - val_dice_coe: 0.8712 - val_accuracy: 0.9902 - val_iou_score: 0.7532
# Training Model Fold 4...
# Epoch 1/20
# 37/37 [==============================] - 40s 464ms/step - loss: 1.7398 - dice_coe: 0.0804 - accuracy: 0.4165 - iou_score: 0.0348 - val_loss: 1.3108 - val_dice_coe: 0.0180 - val_accuracy: 0.9335 - val_iou_score: 0.0153
# Epoch 2/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.7566 - dice_coe: 0.5227 - accuracy: 0.9641 - iou_score: 0.2380 - val_loss: 1.2280 - val_dice_coe: 0.0158 - val_accuracy: 0.9447 - val_iou_score: 0.0164
# Epoch 3/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.3847 - dice_coe: 0.7269 - accuracy: 0.9838 - iou_score: 0.5058 - val_loss: 1.0580 - val_dice_coe: 0.0183 - val_accuracy: 0.9715 - val_iou_score: 0.0361
# Epoch 4/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.3057 - dice_coe: 0.7770 - accuracy: 0.9870 - iou_score: 0.5910 - val_loss: 0.8655 - val_dice_coe: 0.1747 - val_accuracy: 0.9749 - val_iou_score: 0.1345
# Epoch 5/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.2588 - dice_coe: 0.8103 - accuracy: 0.9886 - iou_score: 0.6441 - val_loss: 0.4455 - val_dice_coe: 0.6541 - val_accuracy: 0.9882 - val_iou_score: 0.4559
# Epoch 6/20
# 37/37 [==============================] - 11s 308ms/step - loss: 0.2363 - dice_coe: 0.8279 - accuracy: 0.9892 - iou_score: 0.6723 - val_loss: 0.4015 - val_dice_coe: 0.6696 - val_accuracy: 0.9889 - val_iou_score: 0.5097
# Epoch 7/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.2138 - dice_coe: 0.8436 - accuracy: 0.9905 - iou_score: 0.6975 - val_loss: 0.4146 - val_dice_coe: 0.6504 - val_accuracy: 0.9888 - val_iou_score: 0.5080
# Epoch 8/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2142 - dice_coe: 0.8424 - accuracy: 0.9906 - iou_score: 0.6977 - val_loss: 0.3903 - val_dice_coe: 0.6781 - val_accuracy: 0.9896 - val_iou_score: 0.5325
# Epoch 9/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.2053 - dice_coe: 0.8494 - accuracy: 0.9907 - iou_score: 0.7095 - val_loss: 0.3948 - val_dice_coe: 0.6772 - val_accuracy: 0.9893 - val_iou_score: 0.5300
# Epoch 10/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.1931 - dice_coe: 0.8592 - accuracy: 0.9912 - iou_score: 0.7242 - val_loss: 0.3365 - val_dice_coe: 0.7290 - val_accuracy: 0.9912 - val_iou_score: 0.5899
# Epoch 11/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.1863 - dice_coe: 0.8635 - accuracy: 0.9917 - iou_score: 0.7315 - val_loss: 0.3498 - val_dice_coe: 0.7181 - val_accuracy: 0.9908 - val_iou_score: 0.5782
# Epoch 12/20
# 37/37 [==============================] - 12s 319ms/step - loss: 0.1893 - dice_coe: 0.8606 - accuracy: 0.9917 - iou_score: 0.7278 - val_loss: 0.3375 - val_dice_coe: 0.7215 - val_accuracy: 0.9911 - val_iou_score: 0.5915
# Epoch 13/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.1846 - dice_coe: 0.8652 - accuracy: 0.9916 - iou_score: 0.7351 - val_loss: 0.3495 - val_dice_coe: 0.7171 - val_accuracy: 0.9909 - val_iou_score: 0.5824
# Epoch 14/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.1798 - dice_coe: 0.8688 - accuracy: 0.9918 - iou_score: 0.7407 - val_loss: 0.3380 - val_dice_coe: 0.7110 - val_accuracy: 0.9912 - val_iou_score: 0.5934
# Epoch 15/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.1837 - dice_coe: 0.8649 - accuracy: 0.9920 - iou_score: 0.7351 - val_loss: 0.3386 - val_dice_coe: 0.7106 - val_accuracy: 0.9912 - val_iou_score: 0.5922
# Epoch 16/20
# 37/37 [==============================] - 12s 316ms/step - loss: 0.1758 - dice_coe: 0.8707 - accuracy: 0.9923 - iou_score: 0.7442 - val_loss: 0.3262 - val_dice_coe: 0.7222 - val_accuracy: 0.9917 - val_iou_score: 0.6068
# Epoch 17/20
# 37/37 [==============================] - 12s 318ms/step - loss: 0.1768 - dice_coe: 0.8707 - accuracy: 0.9918 - iou_score: 0.7443 - val_loss: 0.3211 - val_dice_coe: 0.7274 - val_accuracy: 0.9918 - val_iou_score: 0.6121
# Epoch 18/20
# 37/37 [==============================] - 12s 334ms/step - loss: 0.1707 - dice_coe: 0.8751 - accuracy: 0.9923 - iou_score: 0.7513 - val_loss: 0.3181 - val_dice_coe: 0.7295 - val_accuracy: 0.9919 - val_iou_score: 0.6146
# Epoch 19/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.1774 - dice_coe: 0.8698 - accuracy: 0.9921 - iou_score: 0.7427 - val_loss: 0.3214 - val_dice_coe: 0.7267 - val_accuracy: 0.9918 - val_iou_score: 0.6117
# Epoch 20/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.1702 - dice_coe: 0.8756 - accuracy: 0.9923 - iou_score: 0.7515 - val_loss: 0.3162 - val_dice_coe: 0.7316 - val_accuracy: 0.9920 - val_iou_score: 0.6172
# Training Model Fold 5...
# Epoch 1/20
# 37/37 [==============================] - 39s 470ms/step - loss: 1.6215 - dice_coe: 0.0828 - accuracy: 0.5676 - iou_score: 0.0351 - val_loss: 1.1094 - val_dice_coe: 0.0265 - val_accuracy: 0.9670 - val_iou_score: 0.0220
# Epoch 2/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.7430 - dice_coe: 0.5185 - accuracy: 0.9667 - iou_score: 0.2459 - val_loss: 1.2306 - val_dice_coe: 8.5354e-04 - val_accuracy: 0.9759 - val_iou_score: 0.0066
# Epoch 3/20
# 37/37 [==============================] - 12s 332ms/step - loss: 0.3862 - dice_coe: 0.7291 - accuracy: 0.9829 - iou_score: 0.5062 - val_loss: 1.0548 - val_dice_coe: 0.0123 - val_accuracy: 0.9768 - val_iou_score: 0.0302
# Epoch 4/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.3044 - dice_coe: 0.7791 - accuracy: 0.9860 - iou_score: 0.5950 - val_loss: 0.6809 - val_dice_coe: 0.4047 - val_accuracy: 0.9839 - val_iou_score: 0.2443
# Epoch 5/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.2536 - dice_coe: 0.8155 - accuracy: 0.9880 - iou_score: 0.6532 - val_loss: 0.5132 - val_dice_coe: 0.6728 - val_accuracy: 0.9886 - val_iou_score: 0.3803
# Epoch 6/20
# 37/37 [==============================] - 12s 317ms/step - loss: 0.2310 - dice_coe: 0.8318 - accuracy: 0.9889 - iou_score: 0.6798 - val_loss: 0.3949 - val_dice_coe: 0.6957 - val_accuracy: 0.9902 - val_iou_score: 0.4985
# Epoch 7/20
# 37/37 [==============================] - 12s 316ms/step - loss: 0.2276 - dice_coe: 0.8332 - accuracy: 0.9896 - iou_score: 0.6825 - val_loss: 0.3831 - val_dice_coe: 0.6998 - val_accuracy: 0.9896 - val_iou_score: 0.5184
# Epoch 8/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.2103 - dice_coe: 0.8471 - accuracy: 0.9901 - iou_score: 0.7034 - val_loss: 0.3337 - val_dice_coe: 0.7270 - val_accuracy: 0.9913 - val_iou_score: 0.5728
# Epoch 9/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.1953 - dice_coe: 0.8584 - accuracy: 0.9907 - iou_score: 0.7223 - val_loss: 0.3161 - val_dice_coe: 0.7438 - val_accuracy: 0.9919 - val_iou_score: 0.5894
# Epoch 10/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.1991 - dice_coe: 0.8541 - accuracy: 0.9910 - iou_score: 0.7168 - val_loss: 0.3145 - val_dice_coe: 0.7399 - val_accuracy: 0.9919 - val_iou_score: 0.5937
# Epoch 11/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.1907 - dice_coe: 0.8610 - accuracy: 0.9910 - iou_score: 0.7275 - val_loss: 0.2962 - val_dice_coe: 0.7603 - val_accuracy: 0.9924 - val_iou_score: 0.6115
# Epoch 12/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.1809 - dice_coe: 0.8690 - accuracy: 0.9912 - iou_score: 0.7409 - val_loss: 0.2985 - val_dice_coe: 0.7526 - val_accuracy: 0.9923 - val_iou_score: 0.6148
# Epoch 13/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.1823 - dice_coe: 0.8674 - accuracy: 0.9915 - iou_score: 0.7381 - val_loss: 0.2909 - val_dice_coe: 0.7580 - val_accuracy: 0.9925 - val_iou_score: 0.6245
# Epoch 14/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.1820 - dice_coe: 0.8672 - accuracy: 0.9916 - iou_score: 0.7374 - val_loss: 0.2908 - val_dice_coe: 0.7574 - val_accuracy: 0.9925 - val_iou_score: 0.6258
# Epoch 15/20
# 37/37 [==============================] - 12s 313ms/step - loss: 0.1754 - dice_coe: 0.8727 - accuracy: 0.9915 - iou_score: 0.7472 - val_loss: 0.2899 - val_dice_coe: 0.7587 - val_accuracy: 0.9925 - val_iou_score: 0.6238
# Epoch 16/20
# 37/37 [==============================] - 12s 312ms/step - loss: 0.1730 - dice_coe: 0.8745 - accuracy: 0.9919 - iou_score: 0.7491 - val_loss: 0.2862 - val_dice_coe: 0.7635 - val_accuracy: 0.9926 - val_iou_score: 0.6290
# Epoch 17/20
# 37/37 [==============================] - 12s 317ms/step - loss: 0.1769 - dice_coe: 0.8714 - accuracy: 0.9916 - iou_score: 0.7447 - val_loss: 0.2903 - val_dice_coe: 0.7629 - val_accuracy: 0.9924 - val_iou_score: 0.6247
# Epoch 18/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.1721 - dice_coe: 0.8750 - accuracy: 0.9918 - iou_score: 0.7506 - val_loss: 0.2845 - val_dice_coe: 0.7667 - val_accuracy: 0.9926 - val_iou_score: 0.6299
# Epoch 19/20
# 37/37 [==============================] - 12s 315ms/step - loss: 0.1698 - dice_coe: 0.8772 - accuracy: 0.9919 - iou_score: 0.7542 - val_loss: 0.2842 - val_dice_coe: 0.7652 - val_accuracy: 0.9927 - val_iou_score: 0.6316
# Epoch 20/20
# 37/37 [==============================] - 12s 314ms/step - loss: 0.1742 - dice_coe: 0.8728 - accuracy: 0.9919 - iou_score: 0.7469 - val_loss: 0.2837 - val_dice_coe: 0.7653 - val_accuracy: 0.9927 - val_iou_score: 0.6328

# %%
avg_dice = 0
avg_loss = 0

for history in global_history:
  avg_dice += history.history['val_dice_coe'][-1]
  avg_loss += history.history['val_loss'][-1]

print('AVG Dice: ', avg_dice/config.n_folds)
print('AVG val loss: ', avg_loss/config.n_folds)
# Out:
# AVG Dice:  0.8156126737594604
# AVG val loss:  0.23411331176757813
