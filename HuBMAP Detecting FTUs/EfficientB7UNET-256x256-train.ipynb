# %% [markdown]
# ## Imports

# %%
# !pip install efficientnet --upgrade -q
# !pip install segmentation_models -q --upgrade
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# segmentation-models 1.0.1 requires efficientnet==1.0.0, but you have efficientnet 1.1.1 which is incompatible.

# %%
import os
import cv2
import glob
import shutil
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import segmentation_models as sm
import efficientnet.tfkeras as efn
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

from tqdm.notebook import tqdm
from sklearn.model_selection import KFold

import warnings
warnings.simplefilter('ignore')
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# ## Conifg

# %%
sm.set_framework('tf.keras')
sm.framework()
os.environ['SM_FRAMEWORK'] = 'tf.keras'

class Config:
  
  gcs_path = 'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828'
  SEED = 1234

  AUTO = tf.data.experimental.AUTOTUNE

  n_folds = 5
  img_size = [256, 256]
  batch_size = 128

  backbone = 'efficientnetb7'
  epochs = 20
  lr = 1e-4

config = Config()

# %%
try: # detect TPUs
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver() # TPU detection
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except ValueError: # no TPU found, detect GPUs
    #strategy = tf.distribute.MirroredStrategy() # for GPU or multi-GPU machines
    strategy = tf.distribute.get_strategy() # default strategy that works on CPU and single GPU
    #strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy() # for clusters of multi-GPU machines

print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.8.193.250:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.8.193.250:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Number of accelerators:  8

# %% [markdown]
# ## GCS_PATHS

# %%
ALL_TRAINING_FILENAMES = tf.io.gfile.glob(config.gcs_path + '/train/*')
ALL_TRAINING_FILENAMES
# Out:
# ['gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/0486052bb-355.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/095bf7a1f-656.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/1e2425f28-586.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/26dc41664-794.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/2f6ecfcdf-324.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/4ef6695ce-1220.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/54f2eec69-299.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/8242609fa-770.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/aaa6a05cc-134.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/afa5e8098-1125.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/b2dc8411c-213.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/b9a3865fc-772.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/c68fe75ea-1136.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/cb2d976f4-888.tfrec',
#  'gs://kds-a73771649e903d014193a8922ad9a9e622325a9f3af3c4949402f828/train/e79de561c-308.tfrec']

# %%
import re
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)
print('NUM_TRAINING_IMAGES:' )
print(count_data_items(ALL_TRAINING_FILENAMES))
# Out:
# NUM_TRAINING_IMAGES:
# 9580

# %% [markdown]
# ## Creating Folds

# %%
ALL_TRAINING_FILENAMES = np.array(ALL_TRAINING_FILENAMES)

splitter = KFold(n_splits=5, random_state=config.SEED)

train_files = []
valid_files = []

for fold, (trn_, val_) in enumerate(splitter.split(range(len(ALL_TRAINING_FILENAMES)))):
  fold_train_files = ALL_TRAINING_FILENAMES[trn_]
  fold_valid_files = ALL_TRAINING_FILENAMES[val_]
  np.random.shuffle(fold_train_files)
  train_files.append(fold_train_files)
  valid_files.append(fold_valid_files)

# %% [markdown]
# ## Datasets pipeline

# %%
DIM = config.img_size[0]
def _parse_image_function(example_proto,augment = True):
    image_feature_description = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'mask': tf.io.FixedLenFeature([], tf.string)
    }
    single_example = tf.io.parse_single_example(example_proto, image_feature_description)
    image = tf.reshape(tf.io.decode_raw(single_example['image'],out_type=np.dtype('uint8')), (DIM,DIM, 3))
    mask =  tf.reshape(tf.io.decode_raw(single_example['mask'],out_type='bool'), (DIM,DIM,1))
    
    if augment:

        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        if tf.random.uniform(()) > 0.4:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        if tf.random.uniform(()) > 0.5:
            image = tf.image.rot90(image, k=1)
            mask = tf.image.rot90(mask, k=1)

        if tf.random.uniform(()) > 0.45:
            image = tf.image.random_saturation(image, 0.7, 1.3)

        if tf.random.uniform(()) > 0.45:
            image = tf.image.random_contrast(image, 0.8, 1.2)
    
    return tf.cast(image, tf.float32), tf.cast(mask, tf.float32)

def load_dataset(filenames, ordered=False, augment = True):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=config.AUTO)
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(lambda ex: _parse_image_function(ex, augment = augment), num_parallel_calls=config.AUTO)
    return dataset

def get_training_dataset(TRAINING_FILENAMES):
    dataset = load_dataset(TRAINING_FILENAMES)
    dataset = dataset.repeat()
    dataset = dataset.shuffle(128, seed = config.SEED)
    dataset = dataset.batch(config.batch_size,drop_remainder=True)
    dataset = dataset.prefetch(config.AUTO)
    return dataset

def get_validation_dataset(VALIDATION_FILENAMES, ordered=True):
    dataset = load_dataset(VALIDATION_FILENAMES, ordered=ordered, augment = False)
    dataset = dataset.batch(config.batch_size,drop_remainder=True)
    dataset = dataset.prefetch(config.AUTO)
    return dataset

# %%
ds = get_training_dataset(train_files[0])

# %%
for i in ds:
  print(i[0].shape, i[1].shape)
  break
# Out:
# (128, 256, 256, 3) (128, 256, 256, 1)

# %% [markdown]
# ## Metrics

# %%
# https://tensorlayer.readthedocs.io/en/latest/_modules/tensorlayer/cost.html#dice_coe
def dice_coe(output, target, axis = None, smooth=1e-10):
    output = tf.dtypes.cast( tf.math.greater(output, 0.5), tf. float32 )
    target = tf.dtypes.cast( tf.math.greater(target, 0.5), tf. float32 )
    inse = tf.reduce_sum(output * target, axis=axis)
    l = tf.reduce_sum(output, axis=axis)
    r = tf.reduce_sum(target, axis=axis)

    dice = (2. * inse + smooth) / (l + r + smooth)
    dice = tf.reduce_mean(dice, name='dice_coe')
    return dice

# https://www.kaggle.com/kool777/training-hubmap-eda-tf-keras-tpu
def tversky(y_true, y_pred, alpha=0.7, beta=0.3, smooth=1):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1 - y_pred_pos))
    false_pos = K.sum((1 - y_true_pos) * y_pred_pos)
    return (true_pos + smooth) / (true_pos + alpha * false_neg + beta * false_pos + smooth)
def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)
def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return K.pow((1 - tv), gamma)

get_custom_objects().update({"focal_tversky": focal_tversky_loss})

# %% [markdown]
# ## Create Model

# %%
def get_model():
  model = sm.Unet(config.backbone, encoder_weights='imagenet')
  model.compile(optimizer = tf.keras.optimizers.Adam(lr = 0.00005),
                loss = sm.losses.bce_dice_loss,
                metrics=[dice_coe,'accuracy', sm.metrics.iou_score])
  return model

# %%
# Lr function
lr_start = 0.000005
lr_min = 0.00001
lr_max = 0.00000125 * 8 * 64
lr_decay = 0.8
lr_rampup = 3

def lrfn(epoch):
  if epoch <= lr_rampup:
    lr = (lr_max - lr_start)/lr_rampup * epoch + lr_min
  else:
    lr = (lr_max - lr_min) * lr_decay**(epoch - lr_rampup) + lr_min
  return lr

values = [lrfn(i) for i in range(10)]
plt.plot(values)

# %% [markdown]
# ## Run Fold function

# %%
def run_fold(fold, display_plot=True):
  tfiles = train_files[fold]
  vfiles = valid_files[fold]

  K.clear_session()
  with strategy.scope():
    model = get_model()

  checkpoint = tf.keras.callbacks.ModelCheckpoint('./model-fold-%i.h5'%fold,
                                 monitor='val_dice_coe',patience = 10,
                                 mode='max',save_best_only=True)
  
  early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_dice_coe',mode = 'max', patience=10, restore_best_weights=True)

  lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=0)

  print(f'Training Model Fold {fold+1}...')
  history = model.fit(
      get_training_dataset(tfiles),
      epochs = config.epochs,
      steps_per_epoch = 9580//config.batch_size,
      callbacks = [checkpoint, lr_callback, early_stop],
      validation_data = get_validation_dataset(vfiles)
  )

  if display_plot:        
        plt.figure(figsize=(15,5))
        n_e = np.arange(len(history.history['dice_coe']))
        plt.plot(n_e,history.history['dice_coe'],'-o',label='Train dice_coe',color='#ff7f0e')
        plt.plot(n_e,history.history['val_dice_coe'],'-o',label='Val dice_coe',color='#1f77b4')
        x = np.argmax( history.history['val_dice_coe'] ); y = np.max( history.history['val_dice_coe'] )
        xdist = plt.xlim()[1] - plt.xlim()[0]; ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#1f77b4'); plt.text(x-0.03*xdist,y-0.13*ydist,'max dice_coe\n%.2f'%y,size=14)
        plt.ylabel('dice_coe',size=14); plt.xlabel('Epoch',size=14)
        plt.legend(loc=2)
        plt2 = plt.gca().twinx()
        plt2.plot(n_e,history.history['loss'],'-o',label='Train Loss',color='#2ca02c')
        plt2.plot(n_e,history.history['val_loss'],'-o',label='Val Loss',color='#d62728')
        x = np.argmin( history.history['val_loss'] ); y = np.min( history.history['val_loss'] )
        ydist = plt.ylim()[1] - plt.ylim()[0]
        plt.scatter(x,y,s=200,color='#d62728'); plt.text(x-0.03*xdist,y+0.05*ydist,'min loss',size=14)
        plt.ylabel('Loss',size=14)
        plt.legend(loc=3)
        plt.show()

  return history, model

# %% [markdown]
# ## Training the model

# %%
global_history = []
history, _ = run_fold(0)
global_history.append(history)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 3s 0us/step
# Training Model Fold 1...
# Epoch 1/20
# 74/74 [==============================] - 241s 883ms/step - loss: 1.5247 - dice_coe: 0.0897 - accuracy: 0.7060 - iou_score: 0.0341 - val_loss: 1.5824 - val_dice_coe: 0.0970 - val_accuracy: 0.6696 - val_iou_score: 0.0441
# Epoch 2/20
# 74/74 [==============================] - 43s 577ms/step - loss: 1.0973 - dice_coe: 0.6772 - accuracy: 0.9635 - iou_score: 0.1096 - val_loss: 1.2483 - val_dice_coe: 0.4549 - val_accuracy: 0.9040 - val_iou_score: 0.1825
# Epoch 3/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.6245 - dice_coe: 0.8602 - accuracy: 0.9928 - iou_score: 0.3112 - val_loss: 0.7315 - val_dice_coe: 0.7342 - val_accuracy: 0.9758 - val_iou_score: 0.2893
# Epoch 4/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.2707 - dice_coe: 0.8807 - accuracy: 0.9939 - iou_score: 0.6306 - val_loss: 0.9254 - val_dice_coe: 0.3536 - val_accuracy: 0.8821 - val_iou_score: 0.2132
# Epoch 5/20
# 74/74 [==============================] - 43s 576ms/step - loss: 0.1719 - dice_coe: 0.8970 - accuracy: 0.9951 - iou_score: 0.7533 - val_loss: 0.5544 - val_dice_coe: 0.6231 - val_accuracy: 0.9545 - val_iou_score: 0.4793
# Epoch 6/20
# 74/74 [==============================] - 42s 573ms/step - loss: 0.1446 - dice_coe: 0.9052 - accuracy: 0.9953 - iou_score: 0.7904 - val_loss: 0.1212 - val_dice_coe: 0.9243 - val_accuracy: 0.9946 - val_iou_score: 0.8245
# Epoch 7/20
# 74/74 [==============================] - 43s 576ms/step - loss: 0.1225 - dice_coe: 0.9171 - accuracy: 0.9956 - iou_score: 0.8206 - val_loss: 0.1157 - val_dice_coe: 0.9266 - val_accuracy: 0.9948 - val_iou_score: 0.8313
# Epoch 8/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.1116 - dice_coe: 0.9237 - accuracy: 0.9960 - iou_score: 0.8337 - val_loss: 0.1105 - val_dice_coe: 0.9275 - val_accuracy: 0.9947 - val_iou_score: 0.8411
# Epoch 9/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.1196 - dice_coe: 0.9153 - accuracy: 0.9961 - iou_score: 0.8276 - val_loss: 0.1182 - val_dice_coe: 0.9226 - val_accuracy: 0.9947 - val_iou_score: 0.8288
# Epoch 10/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.1068 - dice_coe: 0.9243 - accuracy: 0.9962 - iou_score: 0.8411 - val_loss: 0.1008 - val_dice_coe: 0.9328 - val_accuracy: 0.9951 - val_iou_score: 0.8538
# Epoch 11/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.1034 - dice_coe: 0.9259 - accuracy: 0.9963 - iou_score: 0.8460 - val_loss: 0.1014 - val_dice_coe: 0.9315 - val_accuracy: 0.9950 - val_iou_score: 0.8534
# Epoch 12/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0937 - dice_coe: 0.9342 - accuracy: 0.9963 - iou_score: 0.8572 - val_loss: 0.0992 - val_dice_coe: 0.9331 - val_accuracy: 0.9951 - val_iou_score: 0.8570
# Epoch 13/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0940 - dice_coe: 0.9328 - accuracy: 0.9963 - iou_score: 0.8583 - val_loss: 0.0991 - val_dice_coe: 0.9328 - val_accuracy: 0.9951 - val_iou_score: 0.8569
# Epoch 14/20
# 74/74 [==============================] - 43s 578ms/step - loss: 0.1002 - dice_coe: 0.9265 - accuracy: 0.9964 - iou_score: 0.8515 - val_loss: 0.0985 - val_dice_coe: 0.9336 - val_accuracy: 0.9952 - val_iou_score: 0.8568
# Epoch 15/20
# 74/74 [==============================] - 43s 578ms/step - loss: 0.0932 - dice_coe: 0.9326 - accuracy: 0.9966 - iou_score: 0.8593 - val_loss: 0.0961 - val_dice_coe: 0.9352 - val_accuracy: 0.9953 - val_iou_score: 0.8603
# Epoch 16/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0922 - dice_coe: 0.9338 - accuracy: 0.9966 - iou_score: 0.8595 - val_loss: 0.1027 - val_dice_coe: 0.9305 - val_accuracy: 0.9948 - val_iou_score: 0.8543
# Epoch 17/20
# 74/74 [==============================] - 43s 576ms/step - loss: 0.0946 - dice_coe: 0.9299 - accuracy: 0.9966 - iou_score: 0.8594 - val_loss: 0.0963 - val_dice_coe: 0.9338 - val_accuracy: 0.9952 - val_iou_score: 0.8619
# Epoch 18/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0871 - dice_coe: 0.9370 - accuracy: 0.9965 - iou_score: 0.8682 - val_loss: 0.0959 - val_dice_coe: 0.9343 - val_accuracy: 0.9952 - val_iou_score: 0.8626
# Epoch 19/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0904 - dice_coe: 0.9337 - accuracy: 0.9966 - iou_score: 0.8639 - val_loss: 0.0957 - val_dice_coe: 0.9341 - val_accuracy: 0.9952 - val_iou_score: 0.8627
# Epoch 20/20
# 74/74 [==============================] - 43s 577ms/step - loss: 0.0882 - dice_coe: 0.9353 - accuracy: 0.9967 - iou_score: 0.8659 - val_loss: 0.0946 - val_dice_coe: 0.9352 - val_accuracy: 0.9953 - val_iou_score: 0.8639

# %%
global_history = []
history, _ = run_fold(1)
global_history.append(history)
# Out:
# Training Model Fold 2...
# Epoch 1/20
# 74/74 [==============================] - 248s 895ms/step - loss: 2.0342 - dice_coe: 0.0584 - accuracy: 0.1873 - iou_score: 0.0323 - val_loss: 3.8023 - val_dice_coe: 0.0623 - val_accuracy: 0.1367 - val_iou_score: 0.0322
# Epoch 2/20
# 74/74 [==============================] - 44s 588ms/step - loss: 1.4422 - dice_coe: 0.3390 - accuracy: 0.8199 - iou_score: 0.0566 - val_loss: 1.5690 - val_dice_coe: 0.3683 - val_accuracy: 0.9121 - val_iou_score: 0.0736
# Epoch 3/20
# 74/74 [==============================] - 43s 588ms/step - loss: 1.0837 - dice_coe: 0.7680 - accuracy: 0.9854 - iou_score: 0.1079 - val_loss: 1.0309 - val_dice_coe: 0.8065 - val_accuracy: 0.9918 - val_iou_score: 0.1218
# Epoch 4/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.6328 - dice_coe: 0.8352 - accuracy: 0.9920 - iou_score: 0.3078 - val_loss: 0.7364 - val_dice_coe: 0.6848 - val_accuracy: 0.9808 - val_iou_score: 0.2877
# Epoch 5/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.2855 - dice_coe: 0.8874 - accuracy: 0.9941 - iou_score: 0.6100 - val_loss: 0.3177 - val_dice_coe: 0.8431 - val_accuracy: 0.9946 - val_iou_score: 0.5840
# Epoch 6/20
# 74/74 [==============================] - 44s 595ms/step - loss: 0.1883 - dice_coe: 0.9044 - accuracy: 0.9950 - iou_score: 0.7298 - val_loss: 0.2388 - val_dice_coe: 0.8471 - val_accuracy: 0.9949 - val_iou_score: 0.6836
# Epoch 7/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.1717 - dice_coe: 0.9002 - accuracy: 0.9953 - iou_score: 0.7536 - val_loss: 0.2642 - val_dice_coe: 0.8158 - val_accuracy: 0.9923 - val_iou_score: 0.6603
# Epoch 8/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.1449 - dice_coe: 0.9106 - accuracy: 0.9954 - iou_score: 0.7891 - val_loss: 0.1877 - val_dice_coe: 0.8915 - val_accuracy: 0.9954 - val_iou_score: 0.7560
# Epoch 9/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.1341 - dice_coe: 0.9141 - accuracy: 0.9956 - iou_score: 0.8062 - val_loss: 0.1816 - val_dice_coe: 0.9031 - val_accuracy: 0.9957 - val_iou_score: 0.7640
# Epoch 10/20
# 74/74 [==============================] - 44s 588ms/step - loss: 0.1313 - dice_coe: 0.9154 - accuracy: 0.9961 - iou_score: 0.8073 - val_loss: 0.1779 - val_dice_coe: 0.9132 - val_accuracy: 0.9959 - val_iou_score: 0.7686
# Epoch 11/20
# 74/74 [==============================] - 44s 588ms/step - loss: 0.1159 - dice_coe: 0.9236 - accuracy: 0.9960 - iou_score: 0.8292 - val_loss: 0.1708 - val_dice_coe: 0.9074 - val_accuracy: 0.9959 - val_iou_score: 0.7791
# Epoch 12/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.1134 - dice_coe: 0.9250 - accuracy: 0.9960 - iou_score: 0.8323 - val_loss: 0.1684 - val_dice_coe: 0.9143 - val_accuracy: 0.9959 - val_iou_score: 0.7834
# Epoch 13/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.1114 - dice_coe: 0.9255 - accuracy: 0.9963 - iou_score: 0.8340 - val_loss: 0.1687 - val_dice_coe: 0.9076 - val_accuracy: 0.9960 - val_iou_score: 0.7823
# Epoch 14/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1067 - dice_coe: 0.9286 - accuracy: 0.9963 - iou_score: 0.8399 - val_loss: 0.1690 - val_dice_coe: 0.8923 - val_accuracy: 0.9959 - val_iou_score: 0.7830
# Epoch 15/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1047 - dice_coe: 0.9306 - accuracy: 0.9962 - iou_score: 0.8428 - val_loss: 0.1657 - val_dice_coe: 0.8947 - val_accuracy: 0.9960 - val_iou_score: 0.7871
# Epoch 16/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.1069 - dice_coe: 0.9274 - accuracy: 0.9964 - iou_score: 0.8411 - val_loss: 0.1651 - val_dice_coe: 0.9009 - val_accuracy: 0.9959 - val_iou_score: 0.7884
# Epoch 17/20
# 74/74 [==============================] - 44s 589ms/step - loss: 0.1181 - dice_coe: 0.9153 - accuracy: 0.9964 - iou_score: 0.8302 - val_loss: 0.1633 - val_dice_coe: 0.8953 - val_accuracy: 0.9960 - val_iou_score: 0.7915
# Epoch 18/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.0979 - dice_coe: 0.9333 - accuracy: 0.9963 - iou_score: 0.8519 - val_loss: 0.1635 - val_dice_coe: 0.9019 - val_accuracy: 0.9960 - val_iou_score: 0.7908
# Epoch 19/20
# 74/74 [==============================] - 44s 588ms/step - loss: 0.1052 - dice_coe: 0.9257 - accuracy: 0.9964 - iou_score: 0.8459 - val_loss: 0.1630 - val_dice_coe: 0.9019 - val_accuracy: 0.9960 - val_iou_score: 0.7913
# Epoch 20/20
# 74/74 [==============================] - 43s 588ms/step - loss: 0.1039 - dice_coe: 0.9285 - accuracy: 0.9965 - iou_score: 0.8437 - val_loss: 0.1631 - val_dice_coe: 0.9017 - val_accuracy: 0.9960 - val_iou_score: 0.7917

# %%
global_history = []
history, _ = run_fold(2)
global_history.append(history)
# Out:
# Training Model Fold 3...
# Epoch 1/20
# 74/74 [==============================] - 253s 896ms/step - loss: 1.4468 - dice_coe: 0.0871 - accuracy: 0.7971 - iou_score: 0.0321 - val_loss: 1.6311 - val_dice_coe: 0.0893 - val_accuracy: 0.6310 - val_iou_score: 0.0425
# Epoch 2/20
# 74/74 [==============================] - 42s 573ms/step - loss: 1.0538 - dice_coe: 0.6687 - accuracy: 0.9700 - iou_score: 0.1133 - val_loss: 1.1094 - val_dice_coe: 0.7220 - val_accuracy: 0.9726 - val_iou_score: 0.1615
# Epoch 3/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.5910 - dice_coe: 0.8597 - accuracy: 0.9925 - iou_score: 0.3310 - val_loss: 0.5458 - val_dice_coe: 0.8896 - val_accuracy: 0.9921 - val_iou_score: 0.3805
# Epoch 4/20
# 74/74 [==============================] - 42s 574ms/step - loss: 0.2621 - dice_coe: 0.8728 - accuracy: 0.9937 - iou_score: 0.6402 - val_loss: 1.1595 - val_dice_coe: 0.1360 - val_accuracy: 0.9367 - val_iou_score: 0.0654
# Epoch 5/20
# 74/74 [==============================] - 42s 574ms/step - loss: 0.1704 - dice_coe: 0.8923 - accuracy: 0.9948 - iou_score: 0.7565 - val_loss: 0.1486 - val_dice_coe: 0.9223 - val_accuracy: 0.9939 - val_iou_score: 0.7902
# Epoch 6/20
# 74/74 [==============================] - 43s 582ms/step - loss: 0.1380 - dice_coe: 0.9080 - accuracy: 0.9953 - iou_score: 0.7974 - val_loss: 0.1182 - val_dice_coe: 0.9207 - val_accuracy: 0.9948 - val_iou_score: 0.8380
# Epoch 7/20
# 74/74 [==============================] - 42s 573ms/step - loss: 0.1198 - dice_coe: 0.9181 - accuracy: 0.9959 - iou_score: 0.8220 - val_loss: 0.1152 - val_dice_coe: 0.9332 - val_accuracy: 0.9947 - val_iou_score: 0.8406
# Epoch 8/20
# 74/74 [==============================] - 42s 568ms/step - loss: 0.1194 - dice_coe: 0.9161 - accuracy: 0.9957 - iou_score: 0.8249 - val_loss: 0.1243 - val_dice_coe: 0.9269 - val_accuracy: 0.9939 - val_iou_score: 0.8351
# Epoch 9/20
# 74/74 [==============================] - 42s 574ms/step - loss: 0.1074 - dice_coe: 0.9240 - accuracy: 0.9961 - iou_score: 0.8385 - val_loss: 0.1048 - val_dice_coe: 0.9386 - val_accuracy: 0.9951 - val_iou_score: 0.8563
# Epoch 10/20
# 74/74 [==============================] - 42s 574ms/step - loss: 0.1048 - dice_coe: 0.9244 - accuracy: 0.9961 - iou_score: 0.8439 - val_loss: 0.1038 - val_dice_coe: 0.9387 - val_accuracy: 0.9950 - val_iou_score: 0.8591
# Epoch 11/20
# 74/74 [==============================] - 42s 573ms/step - loss: 0.0997 - dice_coe: 0.9283 - accuracy: 0.9961 - iou_score: 0.8497 - val_loss: 0.0997 - val_dice_coe: 0.9411 - val_accuracy: 0.9952 - val_iou_score: 0.8624
# Epoch 12/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.0977 - dice_coe: 0.9306 - accuracy: 0.9962 - iou_score: 0.8528 - val_loss: 0.0996 - val_dice_coe: 0.9408 - val_accuracy: 0.9953 - val_iou_score: 0.8624
# Epoch 13/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.0932 - dice_coe: 0.9328 - accuracy: 0.9964 - iou_score: 0.8573 - val_loss: 0.0989 - val_dice_coe: 0.9415 - val_accuracy: 0.9953 - val_iou_score: 0.8635
# Epoch 14/20
# 74/74 [==============================] - 43s 576ms/step - loss: 0.0966 - dice_coe: 0.9291 - accuracy: 0.9965 - iou_score: 0.8549 - val_loss: 0.0991 - val_dice_coe: 0.9412 - val_accuracy: 0.9953 - val_iou_score: 0.8635
# Epoch 15/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.0938 - dice_coe: 0.9309 - accuracy: 0.9964 - iou_score: 0.8585 - val_loss: 0.0989 - val_dice_coe: 0.9409 - val_accuracy: 0.9953 - val_iou_score: 0.8636
# Epoch 16/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.0913 - dice_coe: 0.9339 - accuracy: 0.9964 - iou_score: 0.8605 - val_loss: 0.0984 - val_dice_coe: 0.9412 - val_accuracy: 0.9952 - val_iou_score: 0.8654
# Epoch 17/20
# 74/74 [==============================] - 42s 575ms/step - loss: 0.0922 - dice_coe: 0.9318 - accuracy: 0.9965 - iou_score: 0.8599 - val_loss: 0.0979 - val_dice_coe: 0.9413 - val_accuracy: 0.9953 - val_iou_score: 0.8656
# Epoch 18/20
# 74/74 [==============================] - 43s 576ms/step - loss: 0.0885 - dice_coe: 0.9353 - accuracy: 0.9965 - iou_score: 0.8650 - val_loss: 0.0965 - val_dice_coe: 0.9425 - val_accuracy: 0.9954 - val_iou_score: 0.8669
# Epoch 19/20
# 74/74 [==============================] - 42s 575ms/step - loss: 0.0910 - dice_coe: 0.9334 - accuracy: 0.9964 - iou_score: 0.8618 - val_loss: 0.0973 - val_dice_coe: 0.9418 - val_accuracy: 0.9953 - val_iou_score: 0.8659
# Epoch 20/20
# 74/74 [==============================] - 43s 575ms/step - loss: 0.0937 - dice_coe: 0.9309 - accuracy: 0.9965 - iou_score: 0.8596 - val_loss: 0.0967 - val_dice_coe: 0.9421 - val_accuracy: 0.9953 - val_iou_score: 0.8668

# %%
global_history = []
history, _ = run_fold(3)
global_history.append(history)
# Out:
# Training Model Fold 4...
# Epoch 1/20
# 74/74 [==============================] - 254s 903ms/step - loss: 2.0725 - dice_coe: 0.0630 - accuracy: 0.1700 - iou_score: 0.0349 - val_loss: 2.0736 - val_dice_coe: 0.0563 - val_accuracy: 0.2702 - val_iou_score: 0.0295
# Epoch 2/20
# 74/74 [==============================] - 43s 586ms/step - loss: 1.4278 - dice_coe: 0.4338 - accuracy: 0.8055 - iou_score: 0.0678 - val_loss: 1.8845 - val_dice_coe: 0.1796 - val_accuracy: 0.7405 - val_iou_score: 0.0580
# Epoch 3/20
# 74/74 [==============================] - 43s 586ms/step - loss: 1.0030 - dice_coe: 0.8512 - accuracy: 0.9914 - iou_score: 0.1358 - val_loss: 1.1424 - val_dice_coe: 0.7390 - val_accuracy: 0.9931 - val_iou_score: 0.0862
# Epoch 4/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.5522 - dice_coe: 0.8786 - accuracy: 0.9933 - iou_score: 0.3660 - val_loss: 0.7323 - val_dice_coe: 0.7057 - val_accuracy: 0.9900 - val_iou_score: 0.2375
# Epoch 5/20
# 74/74 [==============================] - 44s 596ms/step - loss: 0.2558 - dice_coe: 0.9017 - accuracy: 0.9946 - iou_score: 0.6416 - val_loss: 1.0274 - val_dice_coe: 0.2688 - val_accuracy: 0.9703 - val_iou_score: 0.0988
# Epoch 6/20
# 74/74 [==============================] - 43s 585ms/step - loss: 0.1659 - dice_coe: 0.9171 - accuracy: 0.9950 - iou_score: 0.7558 - val_loss: 0.3481 - val_dice_coe: 0.8825 - val_accuracy: 0.9958 - val_iou_score: 0.5713
# Epoch 7/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1379 - dice_coe: 0.9238 - accuracy: 0.9957 - iou_score: 0.7929 - val_loss: 0.3043 - val_dice_coe: 0.8781 - val_accuracy: 0.9955 - val_iou_score: 0.6272
# Epoch 8/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.1353 - dice_coe: 0.9183 - accuracy: 0.9955 - iou_score: 0.8018 - val_loss: 0.2731 - val_dice_coe: 0.8782 - val_accuracy: 0.9958 - val_iou_score: 0.6685
# Epoch 9/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1207 - dice_coe: 0.9255 - accuracy: 0.9958 - iou_score: 0.8203 - val_loss: 0.2688 - val_dice_coe: 0.8913 - val_accuracy: 0.9958 - val_iou_score: 0.6805
# Epoch 10/20
# 74/74 [==============================] - 43s 585ms/step - loss: 0.1090 - dice_coe: 0.9319 - accuracy: 0.9960 - iou_score: 0.8352 - val_loss: 0.2730 - val_dice_coe: 0.8926 - val_accuracy: 0.9958 - val_iou_score: 0.6748
# Epoch 11/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1059 - dice_coe: 0.9322 - accuracy: 0.9962 - iou_score: 0.8402 - val_loss: 0.2650 - val_dice_coe: 0.8875 - val_accuracy: 0.9959 - val_iou_score: 0.6851
# Epoch 12/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.1039 - dice_coe: 0.9337 - accuracy: 0.9962 - iou_score: 0.8418 - val_loss: 0.2631 - val_dice_coe: 0.8892 - val_accuracy: 0.9959 - val_iou_score: 0.6875
# Epoch 13/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.0982 - dice_coe: 0.9360 - accuracy: 0.9962 - iou_score: 0.8511 - val_loss: 0.2546 - val_dice_coe: 0.8988 - val_accuracy: 0.9960 - val_iou_score: 0.6943
# Epoch 14/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.0958 - dice_coe: 0.9372 - accuracy: 0.9963 - iou_score: 0.8539 - val_loss: 0.2521 - val_dice_coe: 0.9057 - val_accuracy: 0.9961 - val_iou_score: 0.6991
# Epoch 15/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.0959 - dice_coe: 0.9368 - accuracy: 0.9963 - iou_score: 0.8536 - val_loss: 0.2499 - val_dice_coe: 0.9005 - val_accuracy: 0.9961 - val_iou_score: 0.7020
# Epoch 16/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.0916 - dice_coe: 0.9391 - accuracy: 0.9964 - iou_score: 0.8586 - val_loss: 0.2487 - val_dice_coe: 0.9007 - val_accuracy: 0.9961 - val_iou_score: 0.7029
# Epoch 17/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.0911 - dice_coe: 0.9398 - accuracy: 0.9963 - iou_score: 0.8603 - val_loss: 0.2507 - val_dice_coe: 0.8993 - val_accuracy: 0.9961 - val_iou_score: 0.7003
# Epoch 18/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.0895 - dice_coe: 0.9401 - accuracy: 0.9964 - iou_score: 0.8635 - val_loss: 0.2463 - val_dice_coe: 0.9009 - val_accuracy: 0.9962 - val_iou_score: 0.7066
# Epoch 19/20
# 74/74 [==============================] - 43s 586ms/step - loss: 0.0956 - dice_coe: 0.9351 - accuracy: 0.9963 - iou_score: 0.8553 - val_loss: 0.2464 - val_dice_coe: 0.8997 - val_accuracy: 0.9962 - val_iou_score: 0.7071
# Epoch 20/20
# 74/74 [==============================] - 43s 587ms/step - loss: 0.0891 - dice_coe: 0.9403 - accuracy: 0.9965 - iou_score: 0.8624 - val_loss: 0.2467 - val_dice_coe: 0.9021 - val_accuracy: 0.9962 - val_iou_score: 0.7054

# %%
global_history = []
history, _ = run_fold(4)
global_history.append(history)
# Out:
# Training Model Fold 5...
# Epoch 1/20
# 74/74 [==============================] - 254s 909ms/step - loss: 1.6149 - dice_coe: 0.0939 - accuracy: 0.5961 - iou_score: 0.0391 - val_loss: 2.7187 - val_dice_coe: 0.0451 - val_accuracy: 0.2420 - val_iou_score: 0.0239
# Epoch 2/20
# 74/74 [==============================] - 44s 590ms/step - loss: 1.2001 - dice_coe: 0.6257 - accuracy: 0.9355 - iou_score: 0.0980 - val_loss: 1.3257 - val_dice_coe: 0.4190 - val_accuracy: 0.9566 - val_iou_score: 0.0701
# Epoch 3/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.7791 - dice_coe: 0.8635 - accuracy: 0.9917 - iou_score: 0.2230 - val_loss: 0.9544 - val_dice_coe: 0.4538 - val_accuracy: 0.9680 - val_iou_score: 0.1394
# Epoch 4/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.3517 - dice_coe: 0.8889 - accuracy: 0.9935 - iou_score: 0.5394 - val_loss: 1.1712 - val_dice_coe: 0.3230 - val_accuracy: 0.9100 - val_iou_score: 0.1704
# Epoch 5/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.1707 - dice_coe: 0.9145 - accuracy: 0.9946 - iou_score: 0.7498 - val_loss: 0.3857 - val_dice_coe: 0.7689 - val_accuracy: 0.9955 - val_iou_score: 0.5300
# Epoch 6/20
# 74/74 [==============================] - 45s 603ms/step - loss: 0.1377 - dice_coe: 0.9202 - accuracy: 0.9951 - iou_score: 0.7968 - val_loss: 0.3160 - val_dice_coe: 0.8205 - val_accuracy: 0.9959 - val_iou_score: 0.6112
# Epoch 7/20
# 74/74 [==============================] - 44s 589ms/step - loss: 0.1253 - dice_coe: 0.9223 - accuracy: 0.9955 - iou_score: 0.8150 - val_loss: 0.3293 - val_dice_coe: 0.8338 - val_accuracy: 0.9956 - val_iou_score: 0.6091
# Epoch 8/20
# 74/74 [==============================] - 44s 589ms/step - loss: 0.1114 - dice_coe: 0.9291 - accuracy: 0.9957 - iou_score: 0.8337 - val_loss: 0.2816 - val_dice_coe: 0.8584 - val_accuracy: 0.9962 - val_iou_score: 0.6618
# Epoch 9/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.1040 - dice_coe: 0.9323 - accuracy: 0.9958 - iou_score: 0.8448 - val_loss: 0.2846 - val_dice_coe: 0.8546 - val_accuracy: 0.9961 - val_iou_score: 0.6604
# Epoch 10/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.1019 - dice_coe: 0.9322 - accuracy: 0.9960 - iou_score: 0.8470 - val_loss: 0.2816 - val_dice_coe: 0.8443 - val_accuracy: 0.9961 - val_iou_score: 0.6674
# Epoch 11/20
# 74/74 [==============================] - 44s 591ms/step - loss: 0.0949 - dice_coe: 0.9357 - accuracy: 0.9961 - iou_score: 0.8573 - val_loss: 0.2767 - val_dice_coe: 0.8475 - val_accuracy: 0.9963 - val_iou_score: 0.6725
# Epoch 12/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.0909 - dice_coe: 0.9387 - accuracy: 0.9961 - iou_score: 0.8630 - val_loss: 0.2703 - val_dice_coe: 0.8501 - val_accuracy: 0.9963 - val_iou_score: 0.6809
# Epoch 13/20
# 74/74 [==============================] - 44s 589ms/step - loss: 0.0940 - dice_coe: 0.9353 - accuracy: 0.9963 - iou_score: 0.8584 - val_loss: 0.2676 - val_dice_coe: 0.8468 - val_accuracy: 0.9961 - val_iou_score: 0.6824
# Epoch 14/20
# 74/74 [==============================] - 44s 590ms/step - loss: 0.0898 - dice_coe: 0.9388 - accuracy: 0.9963 - iou_score: 0.8630 - val_loss: 0.2651 - val_dice_coe: 0.8476 - val_accuracy: 0.9963 - val_iou_score: 0.6869
# Epoch 15/20
# 74/74 [==============================] - 44s 591ms/step - loss: 0.0875 - dice_coe: 0.9400 - accuracy: 0.9962 - iou_score: 0.8685 - val_loss: 0.2601 - val_dice_coe: 0.8511 - val_accuracy: 0.9963 - val_iou_score: 0.6906
# Epoch 16/20
# 74/74 [==============================] - 44s 592ms/step - loss: 0.0880 - dice_coe: 0.9393 - accuracy: 0.9963 - iou_score: 0.8663 - val_loss: 0.2666 - val_dice_coe: 0.8519 - val_accuracy: 0.9964 - val_iou_score: 0.6868
# Epoch 17/20
# 74/74 [==============================] - 44s 591ms/step - loss: 0.0878 - dice_coe: 0.9393 - accuracy: 0.9964 - iou_score: 0.8673 - val_loss: 0.2633 - val_dice_coe: 0.8479 - val_accuracy: 0.9963 - val_iou_score: 0.6894
# Epoch 18/20
# 74/74 [==============================] - 44s 591ms/step - loss: 0.0826 - dice_coe: 0.9436 - accuracy: 0.9963 - iou_score: 0.8739 - val_loss: 0.2632 - val_dice_coe: 0.8478 - val_accuracy: 0.9963 - val_iou_score: 0.6896

# %% [markdown]
# ## OOF Results

# %%
dice_values = [0.9352, 0.9017, 0.9421, 0.9021, 0.8478]
np.mean(dice_values)
# Out:
# 0.90578
